# %%
print 'Hello World'
# Out:
# Hello World

# %% [markdown]
# # Getting started with Python
#
# ## We have done
# * Installed Python
# * Started IPython Notebook
#
# ## Create some variables in Python

# %%
i = 4 #int

# %%
type(i)
# Out:
# int

# %%
f = 4.1

# %%
type(f)
# Out:
# float

# %%
b = True #boolean

# %%
s = 'This is a string'

# %%
type(s)
# Out:
# str

# %% [markdown]
# ## Advanced Python types

# %%
l = [3, 1, 2]

# %%
d = {'foo':2, 'my first dictionary':'f', 'desk':3.5}

# %%
type(d)
# Out:
# dict

# %%
n = None

# %%
type(n)
# Out:
# NoneType

# %% [markdown]
# ## Advanced printing

# %%
print "Our float value is %f, our integer value is %i" %(f,i)
# Out:
# Our float value is 4.100000, our integer value is 4

# %%
print "Our float value is %s, our integer value is %s" %(f,i)
# Out:
# Our float value is 4.1, our integer value is 4

# %%
print "Out boolean value is %s" %b
# Out:
# Out boolean value is True

# %% [markdown]
# ## Conditional statements in Python

# %%
if i == 1 and f > 4:
    print "The value of i is 1 and f is greater than 4."
elif i > 4 or f > 4:
    print "i and f are both greater than 4"
else:
    print "Both i and f are less than or equal to 4"
# Out:
# i and f are both greater than 4

# %% [markdown]
# ## Conditional loops

# %%
print l
# Out:
# [3, 1, 2]

# %%
for e in l:
    print e
# Out:
# 3
# 1
# 2

# %%
counter = 6
while counter < 10 :
    print counter
    counter += 1
# Out:
# 6
# 7
# 8
# 9

# %% [markdown]
# ## Creating functions in Python

# %%
def add2(x):
    y = x + 2
    return y

# %%
i = 5

# %%
add2(i)
# Out:
# 7

# %%
square = lambda x: x*x

# %%
square(3)
# Out:
# 9
